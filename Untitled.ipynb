# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cufflinks as cf
import plotly.express as px
from datetime import date
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
replace_geslacht = {"T001038":"Totaal mannen en vrouwen",
'3000': 'Mannen', 3000: 'Mannen',
'4000':"Vrouwen"}

replace_leeftijd = {10000 + 100*leeftijd: leeftijd for leeftijd in range(1, 100)}
replace_leeftijd.update({10010:0, 19901:100, 19902:101, 19903:102, 19904:103, 19905:104, 22300:105})

# %% [markdown]
# Download RIVM data

# %%
df_data = pd.read_csv('https://data.rivm.nl/covid-19/COVID-19_aantallen_gemeente_per_dag.csv', sep=';')
df_data.to_csv(f'covid_cases_{date.today()}.csv', index=False)
df_data
# Out:
#              Date_of_report Date_of_publication Municipality_code  \
# 0       2021-07-07 10:00:00          2020-02-27            GM0014
# 1       2021-07-07 10:00:00          2020-02-27            GM0034
# 2       2021-07-07 10:00:00          2020-02-27            GM0037
# 3       2021-07-07 10:00:00          2020-02-27            GM0047
# 4       2021-07-07 10:00:00          2020-02-27            GM0050
# ...                     ...                 ...               ...
# 187861  2021-07-07 10:00:00          2021-07-07               NaN
# 187862  2021-07-07 10:00:00          2021-07-07               NaN
# 187863  2021-07-07 10:00:00          2021-07-07               NaN
# 187864  2021-07-07 10:00:00          2021-07-07               NaN
# 187865  2021-07-07 10:00:00          2021-07-07               NaN
#
#        Municipality_name       Province Security_region_code  \
# 0              Groningen      Groningen                 VR01
# 1                 Almere      Flevoland                 VR25
# 2            Stadskanaal      Groningen                 VR01
# 3                Veendam      Groningen                 VR01
# 4               Zeewolde      Flevoland                 VR25
# ...                  ...            ...                  ...
# 187861               NaN        Limburg                 VR23
# 187862               NaN        Limburg                 VR24
# 187863               NaN   Zuid-Holland                 VR15
# 187864               NaN        Fryslân                 VR02
# 187865               NaN  Noord-Holland                 VR11
#
#         Security_region_name  Municipal_health_service  \
# 0                  Groningen             GGD Groningen
# 1                  Flevoland             GGD Flevoland
# 2                  Groningen             GGD Groningen
# 3                  Groningen             GGD Groningen
# 4                  Flevoland             GGD Flevoland
# ...                      ...                       ...
# 187861         Limburg-Noord         GGD Limburg-Noord
# 187862          Limburg-Zuid          GGD Zuid-Limburg
# 187863            Haaglanden            GGD Haaglanden
# 187864               Fryslân               GGD Fryslân
# 187865  Zaanstreek-Waterland  GGD Zaanstreek/Waterland
#
#                               ROAZ_region  Total_reported  Hospital_admission  \
# 0       Acute Zorgnetwerk Noord Nederland               0                   0
# 1                            SpoedZorgNet               0                   0
# 2       Acute Zorgnetwerk Noord Nederland               0                   0
# 3       Acute Zorgnetwerk Noord Nederland               0                   0
# 4                            SpoedZorgNet               0                   0
# ...                                   ...             ...                 ...
# 187861         Netwerk Acute Zorg Limburg               0                   0
# 187862         Netwerk Acute Zorg Limburg               0                   0
# 187863            Netwerk Acute Zorg West               6                   0
# 187864  Acute Zorgnetwerk Noord Nederland               0                   0
# 187865                                NaN               1                   0
#
#         Deceased
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 187861         0
# 187862         0
# 187863         0
# 187864         0
# 187865         0
#
# [187866 rows x 12 columns]

# %% [markdown]
# Inwonersaantallen 2021 beschikbaar op https://opendata.cbs.nl/statline/portal.html?_la=nl&_catalog=CBS&tableId=03759ned&_theme=266

# %%
def calculate_average_column_per_group(df, column, group):
    if group in df.columns:
        df = df.set_index(group)
        
    aandeel = df[column] * df['aantal_inwoners']
    
    grouped = df.groupby(group)
    
    return aandeel.groupby(group).sum() / grouped['aantal_inwoners'].sum()

# %%
df_inw_aantal = pd.read_csv('03759ned_TypedDataSet_06072021_165631.csv', sep=';', dtype={'Geslacht':str, 'Leeftijd':int})
df_inw_aantal = df_inw_aantal.replace({'Leeftijd':replace_leeftijd})

# Strip the columns
for col in df_inw_aantal.columns:
    df_inw_aantal[col] = df_inw_aantal[col].apply(lambda x: x.strip() if isinstance(x, str) else x)

# Select the rows with the total number of male and female
df_inw_aantal = df_inw_aantal.loc[(df_inw_aantal['Geslacht'].str.contains('T')) & 
                                  (df_inw_aantal['Leeftijd']!=10000) & 
                                  (df_inw_aantal['Leeftijd']!=22000)]

# Drop unimportant columns
df_inw_aantal = df_inw_aantal.drop(columns=['ID', 'Perioden', 'Geslacht', 'BurgerlijkeStaat'])

# Set the index
df_inw_aantal = df_inw_aantal.set_index(['RegioS']).sort_index()

# Calculate average age

aandeel = df_inw_aantal['Leeftijd'] * df_inw_aantal['BevolkingOp1Januari_1']
total_inhab = df_inw_aantal.groupby('RegioS')['BevolkingOp1Januari_1'].sum()
total_inhab.name = 'aantal_inwoners'
avg_age = aandeel.groupby('RegioS').sum() / total_inhab
avg_age.name = 'gemiddelde_leeftijd'

# %%
interessante_gemeentes = ['Westervoort', 'Eindhoven']

# %%
df_test = pd.DataFrame({'gemeente':['AMS', 'AMS', 'ROT', 'ROT'], 'aantal_inwoners':[10, 20, 10, 10], 'value_of_interest':[10, 25, 10, 20]})
calculate_average_column_per_group(df_test, 'value_of_interest', 'gemeente')
# Out:
# gemeente
# AMS    20.0
# ROT    15.0
# dtype: float64

# %%
df_data = pd.read_csv(f'covid_cases_{date.today()}.csv').drop(columns=['Date_of_report']).set_index(['Date_of_publication', 'Municipality_code'])

# Account for municipalities that occur multiple times
df_data.loc[:, ['Total_reported', 'Hospital_admission', 'Deceased']] = df_data.groupby(['Date_of_publication', 'Municipality_code']).sum()[['Total_reported', 'Hospital_admission', 'Deceased']]

# Drop the doubles
df_data = df_data.loc[~df_data.index.duplicated()]

# Add aantal_inwoners and gemiddelde_leeftijd
df_data = df_data.join(avg_age, on='Municipality_code').join(total_inhab, on='Municipality_code').dropna().reset_index().set_index('Date_of_publication')

# Calculate statistics per 100.000 inhabitants
df_data['positieve_tests_per_100k_inwoners'] = df_data['Total_reported'] / df_data['aantal_inwoners'] * 100000
df_data['ziekenhuisopnames_per_100k_inwoners'] = df_data['Hospital_admission'] / df_data['aantal_inwoners'] * 100000
df_data['overleden_per_100k_inwoners'] = df_data['Deceased'] / df_data['aantal_inwoners'] * 100000

df_data.tail()
# Out:
#                     Municipality_code  Municipality_name      Province  \
# Date_of_publication
# 2021-07-07                     GM1966       Het Hogeland     Groningen
# 2021-07-07                     GM1969     Westerkwartier     Groningen
# 2021-07-07                     GM1970  Noardeast-Fryslân       Fryslân
# 2021-07-07                     GM1978        Molenlanden  Zuid-Holland
# 2021-07-07                     GM1979          Eemsdelta     Groningen
#
#                     Security_region_code Security_region_name  \
# Date_of_publication
# 2021-07-07                          VR01            Groningen
# 2021-07-07                          VR01            Groningen
# 2021-07-07                          VR02              Fryslân
# 2021-07-07                          VR18    Zuid-Holland-Zuid
# 2021-07-07                          VR01            Groningen
#
#                           Municipal_health_service  \
# Date_of_publication
# 2021-07-07                           GGD Groningen
# 2021-07-07                           GGD Groningen
# 2021-07-07                             GGD Fryslân
# 2021-07-07           Dienst Gezondheid & Jeugd ZHZ
# 2021-07-07                           GGD Groningen
#
#                                            ROAZ_region  Total_reported  \
# Date_of_publication
# 2021-07-07           Acute Zorgnetwerk Noord Nederland             1.0
# 2021-07-07           Acute Zorgnetwerk Noord Nederland             5.0
# 2021-07-07           Acute Zorgnetwerk Noord Nederland             3.0
# 2021-07-07            Traumacentrum Zuidwest-Nederland             3.0
# 2021-07-07           Acute Zorgnetwerk Noord Nederland             4.0
#
#                      Hospital_admission  Deceased  gemiddelde_leeftijd  \
# Date_of_publication
# 2021-07-07                          0.0       0.0            44.488293
# 2021-07-07                          0.0       0.0            42.459107
# 2021-07-07                          0.0       0.0            42.618808
# 2021-07-07                          0.0       0.0            40.528824
# 2021-07-07                          0.0       0.0            45.382324
#
#                      aantal_inwoners  positieve_tests_per_100k_inwoners  \
# Date_of_publication
# 2021-07-07                   47834.0                           2.090563
# 2021-07-07                   63678.0                           7.852005
# 2021-07-07                   45481.0                           6.596161
# 2021-07-07                   44130.0                           6.798097
# 2021-07-07                   45587.0                           8.774431
#
#                      ziekenhuisopnames_per_100k_inwoners  \
# Date_of_publication
# 2021-07-07                                           0.0
# 2021-07-07                                           0.0
# 2021-07-07                                           0.0
# 2021-07-07                                           0.0
# 2021-07-07                                           0.0
#
#                      overleden_per_100k_inwoners
# Date_of_publication
# 2021-07-07                                   0.0
# 2021-07-07                                   0.0
# 2021-07-07                                   0.0
# 2021-07-07                                   0.0
# 2021-07-07                                   0.0

# %%
se_name_code = df_data.set_index('Municipality_name')['Municipality_code'].dropna().drop_duplicates()
interesting_codes = se_name_code[se_name_code.index.isin(interessante_gemeentes)]
interesting_codes
# Out:
# Municipality_name
# Westervoort    GM0293
# Eindhoven      GM0772
# Name: Municipality_code, dtype: object

# %%
df_data[df_data['Municipality_name'] == 'Westervoort']
# Out:
#                     Municipality_code Municipality_name    Province  \
# Date_of_publication
# 2020-02-27                     GM0293       Westervoort  Gelderland
# 2020-02-28                     GM0293       Westervoort  Gelderland
# 2020-02-29                     GM0293       Westervoort  Gelderland
# 2020-03-01                     GM0293       Westervoort  Gelderland
# 2020-03-02                     GM0293       Westervoort  Gelderland
# ...                               ...               ...         ...
# 2021-07-03                     GM0293       Westervoort  Gelderland
# 2021-07-04                     GM0293       Westervoort  Gelderland
# 2021-07-05                     GM0293       Westervoort  Gelderland
# 2021-07-06                     GM0293       Westervoort  Gelderland
# 2021-07-07                     GM0293       Westervoort  Gelderland
#
#                     Security_region_code Security_region_name  \
# Date_of_publication
# 2020-02-27                          VR07    Gelderland-Midden
# 2020-02-28                          VR07    Gelderland-Midden
# 2020-02-29                          VR07    Gelderland-Midden
# 2020-03-01                          VR07    Gelderland-Midden
# 2020-03-02                          VR07    Gelderland-Midden
# ...                                  ...                  ...
# 2021-07-03                          VR07    Gelderland-Midden
# 2021-07-04                          VR07    Gelderland-Midden
# 2021-07-05                          VR07    Gelderland-Midden
# 2021-07-06                          VR07    Gelderland-Midden
# 2021-07-07                          VR07    Gelderland-Midden
#
#                                               Municipal_health_service  \
# Date_of_publication
df_data.loc[df_data['Municipality_name'].isin(interessante_gemeentes), ['positieve_tests_per_100k_inwoners', 'Municipality_name']].reset_index().drop_duplicates()
# Out:
#     Date_of_publication  positieve_tests_per_100k_inwoners Municipality_name
# 0            2020-02-27                           0.000000       Westervoort
# 1            2020-02-27                           0.000000         Eindhoven
# 2            2020-02-28                           0.000000       Westervoort
# 3            2020-02-28                           0.000000         Eindhoven
# 4            2020-02-29                           0.000000       Westervoort
# ..                  ...                                ...               ...
# 989          2021-07-05                          12.304246         Eindhoven
# 990          2021-07-06                          19.981351       Westervoort
# 991          2021-07-06                          32.669894         Eindhoven
# 992          2021-07-07                           6.660450       Westervoort
# 993          2021-07-07                          29.699904         Eindhoven
#
# [994 rows x 3 columns]

# %%
df_plot = df_data.reset_index().set_index(['Date_of_publication', 'Municipality_name'])
df_plot = df_data.loc[df_data['Municipality_name'].isin(interessante_gemeentes), ['positieve_tests_per_100k_inwoners', 'Municipality_name']].reset_index().drop_duplicates()

hover_data = {'Date_of_publication':False}

fig = px.line(df_plot, x="Date_of_publication", 
              y="positieve_tests_per_100k_inwoners", 
              color='Municipality_name', 
              hover_data=hover_data, 
              category_orders={'Municipality_name':interessante_gemeentes}, 
              template='none', )

fig.update_layout(hovermode='x unified')

fig.update_traces(hovertemplate='%{y}', mode="lines")

fig.show()

# %%
grouped = df_plot.groupby(['Municipality_name'])['positieve_tests_per_100k_inwoners']

# %%
grouped.rolling(7).mean().droplevel(0).sort_index()
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#          ...
# 989     6.849161
# 990     8.563436
# 991    11.152617
# 992     9.514929
# 993    14.849952
# Name: positieve_tests_per_100k_inwoners, Length: 994, dtype: float64

# %%
df_plot['calculated'] = grouped.rolling(7).mean().reset_index(0, drop=True)
df_plot
# Out:
#     Date_of_publication  positieve_tests_per_100k_inwoners Municipality_name  \
# 0            2020-02-27                           0.000000       Westervoort
# 1            2020-02-27                           0.000000         Eindhoven
# 2            2020-02-28                           0.000000       Westervoort
# 3            2020-02-28                           0.000000         Eindhoven
# 4            2020-02-29                           0.000000       Westervoort
# ..                  ...                                ...               ...
# 989          2021-07-05                          12.304246         Eindhoven
# 990          2021-07-06                          19.981351       Westervoort
# 991          2021-07-06                          32.669894         Eindhoven
# 992          2021-07-07                           6.660450       Westervoort
# 993          2021-07-07                          29.699904         Eindhoven
#
#      calculated
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 989    6.849161
# 990    8.563436
# 991   11.152617
# 992    9.514929
# 993   14.849952
#
# [994 rows x 4 columns]

# %%
pd.DataFrame().reset_index()

# %%
(6.66+13.32+6.66+13.32+13.32)/7

# %%
df_plot = df_plot.assign(moving_score=df_plot.groupby(['Municipality_name'])[['positieve_tests_per_100k_inwoners']]
                           .rolling(7, min_periods=1).mean().reset_index(0, drop=True))
df_plot

# %%
df_plot.groupby(['Municipality_name'])[['positieve_tests_per_100k_inwoners']].rolling(7, min_periods=1).mean().reset_index(0, drop=True)

# %%
hover_data = {'Date_of_publication':False}

fig = px.line(df_plot, x="Date_of_publication", 
              y="positieve_tests_per_100k_inwoners", 
              color='Municipality_name', 
              hover_data=hover_data, 
              category_orders={'Municipality_name':interessante_gemeentes}, 
              template='none', )

fig.update_layout(hovermode='x unified')

fig.update_traces(hovertemplate='%{y}', mode="lines")

fig.show()
